# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Bengaluru_House_data.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
df.isnull().sum().sum()
# Out:
# 6201

# %%
#fill the null values

df1 = df.copy()
df1.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df1['society'].fillna("Info Not available",inplace = True)
df1.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#               society total_sqft  bath  balcony   price
# 0             Coomee        1056   2.0      1.0   39.07
# 1             Theanmp       2600   5.0      3.0  120.00
# 2  Info Not available       1440   2.0      3.0   62.00
# 3             Soiewre       1521   3.0      1.0   95.00
# 4  Info Not available       1200   2.0      1.0   51.00

# %%
df1['size'].fillna('0',inplace = True)
df1.total_sqft.isnull().sum()
# Out:
# 0

# %%
def convert_sqft_to_num(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None
    
df1.total_sqft = df1.total_sqft.apply(convert_sqft_to_num)
df1.total_sqft.isnull().sum()
# Out:
# 46

# %%
df1['bhk'] = df1['size'].apply(lambda x : int(x.split()[0]))
df1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size             society  total_sqft  bath  balcony   price  bhk
# 0          2 BHK             Coomee       1056.0   2.0      1.0   39.07    2
# 1      4 Bedroom             Theanmp      2600.0   5.0      3.0  120.00    4
# 2          3 BHK  Info Not available      1440.0   2.0      3.0   62.00    3
# 3          3 BHK             Soiewre      1521.0   3.0      1.0   95.00    3
# 4          2 BHK  Info Not available      1200.0   2.0      1.0   51.00    2
# ...          ...                 ...         ...   ...      ...     ...  ...
# 13315  5 Bedroom             ArsiaEx      3453.0   4.0      0.0  231.00    5
# 13316      4 BHK  Info Not available      3600.0   5.0      NaN  400.00    4
# 13317      2 BHK             Mahla T      1141.0   2.0      1.0   60.00    2
# 13318      4 BHK             SollyCl      4689.0   4.0      1.0  488.00    4
# 13319      1 BHK  Info Not available       550.0   1.0      1.0   17.00    1
#
# [13320 rows x 10 columns]

# %%
df1['price_per_sqr'] = round(df1['price'] * 100000 / df1['total_sqft'],2) 
df1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size             society  total_sqft  bath  balcony   price  bhk  \
# 0          2 BHK             Coomee       1056.0   2.0      1.0   39.07    2
# 1      4 Bedroom             Theanmp      2600.0   5.0      3.0  120.00    4
# 2          3 BHK  Info Not available      1440.0   2.0      3.0   62.00    3
# 3          3 BHK             Soiewre      1521.0   3.0      1.0   95.00    3
# 4          2 BHK  Info Not available      1200.0   2.0      1.0   51.00    2
# ...          ...                 ...         ...   ...      ...     ...  ...
# 13315  5 Bedroom             ArsiaEx      3453.0   4.0      0.0  231.00    5
# 13316      4 BHK  Info Not available      3600.0   5.0      NaN  400.00    4
# 13317      2 BHK             Mahla T      1141.0   2.0      1.0   60.00    2
# 13318      4 BHK             SollyCl      4689.0   4.0      1.0  488.00    4
# 13319      1 BHK  Info Not available       550.0   1.0      1.0   17.00    1
#
#        price_per_sqr
# 0            3699.81
# 1            4615.38
# 2            4305.56
# 3            6245.89
# 4            4250.00
# ...              ...
# 13315        6689.83
# 13316       11111.11
# 13317        5258.55
# 13318       10407.34
# 13319        3090.91
#
# [13320 rows x 11 columns]

# %%
df1.location.unique()
# Out:
# array(['Electronic City Phase II', 'Chikka Tirupathi', 'Uttarahalli', ...,
#        '12th cross srinivas nagar banshankari 3rd stage',
#        'Havanur extension', 'Abshot Layout'], dtype=object)

# %%
len(df1.location.unique())
# Out:
# 1306

# %%
location_stats = df1['location'].value_counts() 
location_stats
# Out:
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# Abshot Layout                       1
# Name: location, Length: 1305, dtype: int64

# %%
below_10_dp = location_stats[location_stats <= 10]
below_10_dp
# Out:
# Kalkere                           10
# Gunjur Palya                      10
# Dodsworth Layout                  10
# BTM 1st Stage                     10
# Sadashiva Nagar                   10
#                                   ..
# Bapuji Layout                      1
# 1st Stage Radha Krishna Layout     1
# BEML Layout 5th stage              1
# singapura paradise                 1
# Abshot Layout                      1
# Name: location, Length: 1064, dtype: int64

# %%
df1['location'] = df1['location'].apply(lambda x : 'Others' if x in below_10_dp else x)
df1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move                    Others
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size             society  total_sqft  bath  balcony   price  bhk  \
# 0          2 BHK             Coomee       1056.0   2.0      1.0   39.07    2
# 1      4 Bedroom             Theanmp      2600.0   5.0      3.0  120.00    4
# 2          3 BHK  Info Not available      1440.0   2.0      3.0   62.00    3
# 3          3 BHK             Soiewre      1521.0   3.0      1.0   95.00    3
# 4          2 BHK  Info Not available      1200.0   2.0      1.0   51.00    2
# ...          ...                 ...         ...   ...      ...     ...  ...
# 13315  5 Bedroom             ArsiaEx      3453.0   4.0      0.0  231.00    5
# 13316      4 BHK  Info Not available      3600.0   5.0      NaN  400.00    4
# 13317      2 BHK             Mahla T      1141.0   2.0      1.0   60.00    2
# 13318      4 BHK             SollyCl      4689.0   4.0      1.0  488.00    4
# 13319      1 BHK  Info Not available       550.0   1.0      1.0   17.00    1
#
#        price_per_sqr
# 0            3699.81
# 1            4615.38
# 2            4305.56
# 3            6245.89
# 4            4250.00
# ...              ...
# 13315        6689.83
# 13316       11111.11
# 13317        5258.55
# 13318       10407.34
# 13319        3090.91
#
# [13320 rows x 11 columns]

# %%
df2 = df1.copy()

# %%
df3 = df2[~(df2.total_sqft/df2.bhk < 300)]
df3.shape
# Out:
# (12576, 11)

# %%
df3.price_per_sqr.describe()
# Out:
# count     12530.000000
# mean       6303.979369
# std        4162.238008
# min         267.830000
# 25%        4210.530000
# 50%        5294.120000
# 75%        6916.670000
# max      176470.590000
# Name: price_per_sqr, dtype: float64

# %%
df1.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size               0
# society            0
# total_sqft        46
# bath              73
# balcony          609
# price              0
# bhk                0
# price_per_sqr     46
# dtype: int64

# %%
df2.shape
# Out:
# (13320, 11)

# %%
df2=df.fillna(value=0)

# %%
df2.shape
# Out:
# (13320, 9)

# %%
df11 =df1.dropna()
df11
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size             society  total_sqft  bath  balcony   price  bhk  \
# 0          2 BHK             Coomee       1056.0   2.0      1.0   39.07    2
# 1      4 Bedroom             Theanmp      2600.0   5.0      3.0  120.00    4
# 2          3 BHK  Info Not available      1440.0   2.0      3.0   62.00    3
# 3          3 BHK             Soiewre      1521.0   3.0      1.0   95.00    3
# 4          2 BHK  Info Not available      1200.0   2.0      1.0   51.00    2
# ...          ...                 ...         ...   ...      ...     ...  ...
# 13314      3 BHK             SoosePr      1715.0   3.0      3.0  112.00    3
# 13315  5 Bedroom             ArsiaEx      3453.0   4.0      0.0  231.00    5
# 13317      2 BHK             Mahla T      1141.0   2.0      1.0   60.00    2
# 13318      4 BHK             SollyCl      4689.0   4.0      1.0  488.00    4
# 13319      1 BHK  Info Not available       550.0   1.0      1.0   17.00    1
#
#        price_per_sqr
# 0            3699.81
# 1            4615.38
# 2            4305.56
# 3            6245.89
# 4            4250.00
# ...              ...
# 13314        6530.61
# 13315        6689.83
# 13317        5258.55
# 13318       10407.34
# 13319        3090.91
#
# [12668 rows x 11 columns]

# %%
df12 =df2.dropna()
df12
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK        0       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK        0       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK        0       3600   5.0      0.0  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK        0        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
df2.isnull.sum()
df2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14884\2332401396.py in <module>
# ----> 1 df2.isnull.sum()
#       2 df2
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
df13 =df1.dropna(how = 'any')
df13

#drops the rows that contain null values using the parameter how
#how can take 2 values : 'any ' or 'oll'
#any: if any one of the row values contain a null value then that row is dropped
#all: if all the row values contain null value then onle those particular rows are dropped
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size             society  total_sqft  bath  balcony   price  bhk  \
# 0          2 BHK             Coomee       1056.0   2.0      1.0   39.07    2
# 1      4 Bedroom             Theanmp      2600.0   5.0      3.0  120.00    4
# 2          3 BHK  Info Not available      1440.0   2.0      3.0   62.00    3
# 3          3 BHK             Soiewre      1521.0   3.0      1.0   95.00    3
# 4          2 BHK  Info Not available      1200.0   2.0      1.0   51.00    2
# ...          ...                 ...         ...   ...      ...     ...  ...
# 13314      3 BHK             SoosePr      1715.0   3.0      3.0  112.00    3
# 13315  5 Bedroom             ArsiaEx      3453.0   4.0      0.0  231.00    5
# 13317      2 BHK             Mahla T      1141.0   2.0      1.0   60.00    2
# 13318      4 BHK             SollyCl      4689.0   4.0      1.0  488.00    4
# 13319      1 BHK  Info Not available       550.0   1.0      1.0   17.00    1
#
#        price_per_sqr
# 0            3699.81
# 1            4615.38
# 2            4305.56
# 3            6245.89
# 4            4250.00
# ...              ...
# 13314        6530.61
# 13315        6689.83
# 13317        5258.55
# 13318       10407.34
# 13319        3090.91
#
# [12668 rows x 11 columns]

# %%
df5 =df1.fillna(method = 'bfill', axis = 1)
df5
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move                    Others
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size             society total_sqft bath balcony  price bhk  \
# 0          2 BHK             Coomee      1056.0  2.0     1.0  39.07   2
# 1      4 Bedroom             Theanmp     2600.0  5.0     3.0  120.0   4
# 2          3 BHK  Info Not available     1440.0  2.0     3.0   62.0   3
# 3          3 BHK             Soiewre     1521.0  3.0     1.0   95.0   3
# 4          2 BHK  Info Not available     1200.0  2.0     1.0   51.0   2
# ...          ...                 ...        ...  ...     ...    ...  ..
# 13315  5 Bedroom             ArsiaEx     3453.0  4.0     0.0  231.0   5
# 13316      4 BHK  Info Not available     3600.0  5.0   400.0  400.0   4
# 13317      2 BHK             Mahla T     1141.0  2.0     1.0   60.0   2
# 13318      4 BHK             SollyCl     4689.0  4.0     1.0  488.0   4
# 13319      1 BHK  Info Not available      550.0  1.0     1.0   17.0   1
#
#       price_per_sqr
# 0           3699.81
# 1           4615.38
# 2           4305.56
# 3           6245.89
# 4            4250.0
# ...             ...
# 13315       6689.83
# 13316      11111.11
# 13317       5258.55
# 13318      10407.34
# 13319       3090.91
#
# [13320 rows x 11 columns]

# %%
df6 =df1.dropna(how = 'all')
df6
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move                    Others
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size             society  total_sqft  bath  balcony   price  bhk  \
# 0          2 BHK             Coomee       1056.0   2.0      1.0   39.07    2
# 1      4 Bedroom             Theanmp      2600.0   5.0      3.0  120.00    4
# 2          3 BHK  Info Not available      1440.0   2.0      3.0   62.00    3
# 3          3 BHK             Soiewre      1521.0   3.0      1.0   95.00    3
# 4          2 BHK  Info Not available      1200.0   2.0      1.0   51.00    2
# ...          ...                 ...         ...   ...      ...     ...  ...
# 13315  5 Bedroom             ArsiaEx      3453.0   4.0      0.0  231.00    5
# 13316      4 BHK  Info Not available      3600.0   5.0      NaN  400.00    4
# 13317      2 BHK             Mahla T      1141.0   2.0      1.0   60.00    2
# 13318      4 BHK             SollyCl      4689.0   4.0      1.0  488.00    4
# 13319      1 BHK  Info Not available       550.0   1.0      1.0   17.00    1
#
#        price_per_sqr
# 0            3699.81
# 1            4615.38
# 2            4305.56
# 3            6245.89
# 4            4250.00
# ...              ...
# 13315        6689.83
# 13316       11111.11
# 13317        5258.55
# 13318       10407.34
# 13319        3090.91
#
# [13320 rows x 11 columns]

# %%
function gradientDescent(){
    var learning_rate = 0.05;
    for(var i=0; i<data.length;i++){
        var x = data[i].x;
        var y = data[i].y;
        var guess = m*x+b;
        var error = y
    }
}
